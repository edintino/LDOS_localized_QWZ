# %%
# %pylab inline
import sys
import os
import fnmatch
import pickle
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
uu = 1.0
dd = 2.0
data = pickle.load( open("u" + str(round(uu,2)) + "d" + str(round(dd,2)) + "/data_u" + str(round(uu,2)) + "d" + str(round(dd,2)) + ".p", "rb"))

# %%
ldos = []
for rseeds in data.keys():
    ldos.append(data[str(rseeds)])
ldos = array(ldos)

# %%
energies = np.linspace(0,1,200)
for jj in arange(10,75,3):
    data = [ldos[ii][jj] for ii in range(len(ldos)) if ldos[ii][jj] >= 0]
    mean_data = mean(data)
    data /= mean_data
    hist(data, bins = np.linspace(0,5,100))
    title("scaled energy = " + str(round(energies[jj],3)))
    ylabel("Number of LDOS")
    xlabel("LDOS")
    xlim((0,5))
    show()
